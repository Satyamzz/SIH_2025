# %%
from demo_data import get_demo_data
import numpy as np
import pandas as pd

# %%
demo=get_demo_data()
alumni=demo["alumni"]
alum=pd.DataFrame(alumni)

# %%
alum.head(10)
# Out:
#                   name                designation  graduation_year  \
# 0         Satyam Singh             AI/ML Engineer             2024
# 1  Rewant Bhriguvanshi          Software Engineer             2023
# 2        Krishna Yadav            Startup Founder             2025
# 3         Garvit Gupta          Software Engineer             2025
# 4       Shubhika Sinha  Machine Learning Engineer             2023
# 5         Prayas Yadav          Software Engineer             2024
# 6        Shreyas Singh              VLSI Engineer             2022
# 7          Kirti Yadav              VLSI Engineer             2021
# 8       Raghav Agrawal         Embedding Engineer             2025
# 9       Gurhans Grover         Startup Co-Founder             2023
#
#           company          location                       email  \
# 0          NVIDIA  Bengaluru, India    satyam.singh@example.com
# 1          Google  Hyderabad, India        rewant.b@example.com
# ...

# %%
alum["company"].value_counts()
# Out:
# company
# NVIDIA             1
# Google             1
# NeuraCore Tech     1
# Flipkart           1
# TCS Research       1
# Uber               1
# Qualcomm           1
# AMD                1
# IIT Delhi Lab      1
# JuvoAI             1
# Paytm              1
# Accenture          1
# Ola Electric       1
# Polygon Labs       1
# Adobe              1
# KPMG               1
# Swiggy             1
# Aether Robotics    1
# IIIT Hyderabad     1
# PhonePe            1
# Name: count, dtype: int64

# %%
companies=[comp["company"] for comp in alumni]
companies.unique_value()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 2
#       1 companies=[comp["company"] for comp in alumni]
# ----> 2 companies.unique_value()
#
# AttributeError: 'list' object has no attribute 'unique_value'
